# %% [markdown]
# <a href="https://colab.research.google.com/github/nherreno/MetNumUN2022II/blob/main/LAB3/nherreno_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![nherrenoDataVisualizationwithPython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![nherrenoDataAnalysiswithPython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![nherrenoPythonforDataScience.jpg](data:image/jpeg;base64,...)
